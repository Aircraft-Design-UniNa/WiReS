# %% [markdown]
# <h1 class="heading">Wind Reconstructor</h1>
# <h1>Actuator Line Model - Case (4,1) - Random trajectories</h1>
#
# <h6 class="author"> — <b style="color:rgb(0,51,102);">Carmine Varriale, Agostino De Marco</b>, <i>University of Naples Federico II</i></h6>
#
# ## Introduction
# In this notebook, we are going to simulate the flight of our aircraft through the middle of the wake of a wind turbine.
# The aircraft is a modified version of the Cessna 172 Skyhawk: it has been scaled down from a geometric and inertial point of view, in order to be closer to an Ikarus C42, for which some theoretical results are available from a previous study. The aerodynamic model has not been changed at all, considering that the two aircraft have comparable configurations overall.
# <br><br>
# The turbine is represented by an actuator line model, and the inflow by a uniform velocity field.

# %%
% run ./python/nb_init.py
% matplotlib inline

import numpy as np
import utm

import geography as geo
import data_handling as dh
from property_map import pmap
from MCSim import *
# Out:
# <style>
#
# /* Hide top Jupyter bar with logo, filename, last saved, etc. */
# div#header-container {
#     display: none;
# }
#
# #notebook-container {
#     padding: 15px;
#     background-color: #fff;
#     min-height: 0;
#     -webkit-box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.2);
#     box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.2);
#     width: 1050px;
# }
#
#
#
# /* ==================================== */
# /*  Code Cells: selected and unselected */
# /* ==================================== */
#
# /*This prevents scrollable output from having an ugly grey shadow around it*/
#
# div.cell, div.output.output_scroll {
#     box-shadow: none;
# }
#
# /* Interactive figure header */
# .ui-widget-header {
#     border-width: 2px 0px 0px 0px;
#     border-radius: 15px;
#     border-top: solid black;
#     background: white;
#     color: black;
#     font-weight: 800;
# }
#
# /* ============= */
# /* Markdown text */
# /* ============= */
#
# .text_cell_render p,
# .text_cell_render div.main {                     /* Basic Font in Markdown cells */
#     font-family: 'Georgia', serif;
#     font-size: 12pt;
#     line-height: 120%;
#     color: black;
#     font-weight: 100;
#     text-align: justify;
#     display: block;
#     padding: 0px;
#     margin-top: 0pt;
#     margin-bottom: 0pt;
# }
#
# .text_cell_render li {
#     font-family: 'Georgia', serif;
#     font-size: 12pt;
#     line-height: 110%;
#     color: black;
#     font-weight: 100;
#     margin-top: 10pt;
# }
#
# .text_cell_render div.path { /* File and folder paths */
#     font-family: 'Lucida Sans Typewriter', monospace;
#     font-size: 10pt;
#     line-height: 100%;
#     color: black;
#     font-weight: 100;
#     text-align: center;
#     display: block;
#     margin: 8pt 0pt 8pt 0pt;
# }
#
# .text_cell_render div.typewr, .text_cell_render span.typewr { /* Code quotations in markdoown cell */
#     font-family: 'Lucida Sans Typewriter', monospace;
#     font-size: 10pt;
#     line-height: 100%;
#     color: black;
#     font-weight: 100;
#     text-align: center;
#     display: inline;
#     margin: 0pt;
# }
#
# .text_cell_render div.button, .text_cell_render span.button { /* Buttons on keyboard */
#     font-family: 'Calibri', sans;
#     font-size: 10pt;
#     line-height: 100%;
#     color: black;
#     font-weight: 100;
#     text-align: center;
#     display: inline;
#     padding: 0pt 2pt 0pt 2pt;
#     border: solid 1pt black;
#     border-radius: 2px;
# }
#
# .text_cell_render span.varstr {  /* Variable of type string */
#     color: #CC0000;
# }
#
# .text_cell_render span.varnum {  /* Variable of type number */
#     color: #00994C;
# }
#
# .text_cell_render span.varbool {  /* Variable of type bool */
#     color: #3333FF;
# }
#
#
# .text_cell_render h1.heading { /* Heading */
#     font-family: 'Times', serif;
#     font-style: regular;
#     font-weight: 600;
#     font-size: 24pt;
#     line-height: 100%;
#     text-align: center;
#     background-color: rgb(0,51,102);
#     color: white;
#     margin: 0.0em 0.0em 0.0em 0.0em;
#     padding: 0.3em 0.0em 0.3em 0.0em;
#     display: block;
# }
#
# .text_cell_render h1 { /* Title */
#     font-family: 'Times', serif;
#     font-style: regular;
#     font-weight: 600;
#     font-size: 24pt;
#     line-height: 100%;
#     text-align: center;
#     color: rgb(0,51,102);
#     background-color: #fff;
#     border-style: solid;
#     border-width: 1.5pt;
#     border-color: rgb(0,51,102);
#     margin: auto;
#     margin-bottom: 0.8em;
#     padding: 0.5em;
#     display: block;
# }
#
# .text_cell_render h2 { /* Section */
#     font-family: 'Times', serif;
#     font-weight: 600;
#     font-size: 20pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     padding-top: 0.9em;
#     padding-bottom: 0.3em;
#     margin-bottom: 0.0em;
#     margin-top: 0.0em;
#     display: block;
# }
#
# .text_cell_render h3 { /* Subsection */
#     font-family: 'Times', serif;
#     font-size: 16pt;
#     font-weight: 600;
#     margin-top:0.0em;
#     margin-bottom: 0.0em;
#     padding-top: 0.7em;
#     padding-bottom: 0.3em;
#     font-style: regular;
#     color: rgb(0,51,102);
# }
#
# .text_cell_render h4 {    /* Caption */
#     font-family: 'Times', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /* Small titles */
#     font-family: 'Times', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6.author { /* Author heading */
#     font-family: 'PT Mono', sans-serif;
#     font-style: normal;
#     font-weight: 500;
#     font-size: 10pt;
#     line-height: 100%;
#     color: black;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
#
# .text_cell_render h6.copyright { /* Copyright note */
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# </style>
#
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %% [markdown]
# ## Case specific settings
# Wind speed at the actuator disk is $5\ \mathrm{m/s}$. <br>
# Wind direction is $270°$ ccw with respect to local north, but the turbine azimuth angle is $285°$, i.e it is working with $15°$ out-of-axis wind.
# <br>
# <img src="./images/ALM42wakeFromAbove300.png" />
# <img src="./images/ALM42wakeFromAboveUz300.png" />

# %%
# Turbine diameter
D_t = 126 #m

# Min and Max distance from the disk, in terms of turbine diameters
minD_t = -0.8 ; maxD_t = 18

# Assign turbine Lat-Lon coordinates and height
Lat_t = 53.153588 #deg
Lon_t = 8.162655  #deg
H_t   = 90      #m

# Calculate turbine UTM coordinates
X_t, Y_t, zone_num, zone_lett = utm.from_latlon(Lat_t, Lon_t)
print("X_t =  {0:.14f} m (Easting coord.)".format(X_t), sep="")
print("Y_t =  {0:.14f} m (Northing coord.)".format(Y_t), sep="")
# Out:
# X_t =  444005.64156725001521 m (Easting coord.)
# Y_t =  5889683.58956928178668 m (Northing coord.)

# %% [markdown]
# <div class="main">
# At this point, we can <b>manually</b> translate the whole mesh in order to give the turbine the above coordinates in UTM reference frame. By default, the simulation has been run with turbine base position being $(0.0 , 0.0, -90.0)\ \mathrm{m}$ and tower height being $90.0\ \mathrm{m}$, so the center of the disk is supposed to be at $z_t =0.0\ \mathrm{m}$.
# <br><br>
# The command to run in the OpenFoam case directory in order to translate the mesh is derived as follows

# %%
x_t = 0.0; y_t = 0.0; z_t = 0.0;

delta_X = X_t - x_t
delta_Y = Y_t - y_t
delta_Z = H_t - z_t

print('transformPoints -translate "(',delta_X,' ',delta_Y,' ',delta_Z,')"', ' >& log.transformPoints &', sep='')
# Out:
# transformPoints -translate "(444005.64156725 5889683.589569282 90.0)" >& log.transformPoints &

# %% [markdown]
# For a quick check on mesh quality, it might be worth to also execute
# <div class="path">checkMesh >& log.checkMesh &</div>
# </div>
#
# At this point, we have the full set of initial and corresponding final positions of the aircraft. Our goal is to create a simulation family for each of this couples: within the family, initial speed will be fixed while initial position with respect to the turbine will vary, thanks to the already well known <span class="typewr">generate_series</span> function. Finally, the aircraft initial speed and altitude will also be iterated in the set, through a simple external <span class="typewr">for</span> loop.
#
# ## Simulation control panel

# %%
for i in range(0,10):  #100 simulations in total, 10 at a time for memory reasons
    
    N = 10
    script     = 'c172mod_OF_ALM_random'
    autopilot  = 'c172ap_unina_mod'
    output_fol = 'c172mod_OF_ALM42_random-' + str(i) 

    # Creating instance of the class
    ALM42r = WRSimFamily(N, 
                        seed_name      = script,
                        autopilot_name = autopilot,
                        out_foldername = output_fol,
                        port_num=1025)

    # Initial position
    X0 = ALM42r.generate_series('', 'uniform', [X_t + minD_t*D_t, X_t + maxD_t*D_t])
    Y0 = Y_t - 1500

    # Calculate waypoints positions in UTM
    X1 = ALM42r.generate_series('', 'uniform', [X_t + minD_t*D_t, X_t + maxD_t*D_t])
    Y1 = Y_t + 1500

    # Convert such positions to Lat-Lon coordinates
    def LatLon_from_utm(X, Y, zone_num, zone_lett):
        LatLon = [utm.to_latlon(X[i], Y, zone_num, zone_lett) for i in range(N)]
        Lat = [LatLon[i][0] for i in range(len(X))] #deg
        Lon = [LatLon[i][1] for i in range(len(X))] #deg
        return Lat, Lon

    Lat0, Lon0 = LatLon_from_utm(X0, Y0, zone_num, zone_lett)
    Lat1, Lon1 = LatLon_from_utm(X1, Y1, zone_num, zone_lett)

    # Initial positions
    ALM42r.generate_series('latitude', 'from_list', Lat0)
    ALM42r.generate_series('longitude', 'from_list', Lon0)

    # Waypoint positions
    ALM42r.generate_series('guidance/target-wp-latitude-rad-final',  'from_list', np.radians(Lat1))
    ALM42r.generate_series('guidance/target-wp-longitude-rad-final', 'from_list', np.radians(Lon1))

    # Flight parameters
    h_m       = ALM42r.generate_series('altitude', 'gaussian', [H_t+25, 5])
    psi_deg   = ALM42r.set_value('psi', 0)
    gamma_deg = ALM42r.set_value('gamma', -1)
    V_kts     = ALM42r.generate_series('vt', 'uniform', [50, 100])

    # Launch family of simulations
    #ALM42r.launch_mc_sim(log='off', system='linux')

# %% [markdown]
# Now we will have to merge files ad folders accordingly. This can be done manually or via a bash script, for example

# %%
GrAll = PostGroup('c172mod_OF_ALM42_random', 'c172x_unina_mod', list(range(1,100+1)),'All')
#GrAll.get_traj_in_UTM()
GrAll.load_traj_in_UTM()
# Out:
# Total time required: 202.27 s

# %% [markdown]
# ## Trajectory

# %%
GrAll.plot_ground_track_UTM(origin=[X_t, Y_t], ax_lim=[None, None, -1510, +1510])
# Out:
# Total time required: 4.23 s

# %%
GrAll.plot_vars('h_agl_m')
# Out:
# Total time required: 1.73 s

# %%
GrAll.plot_traj3D_UTM(origin=[X_t, Y_t], Hdisk=H_t, to_scale='XY', ax_lim=[0,2600,-1600,1600,30,140], \
                    nticks=[11,11,12], view=(40,160), legend='off')
# Out:
# Total time required: 5.01 s

# %% [markdown]
# ## Wind speed in UTM reference frame
# We look at the Eastern component to understand when the aircraft actually enters the wake for the wind deficit makes it as clear as possible. We therefore use this time history as a visual reference for our further observations.

# %%
GrAll.plot_vars('Vw_E_kts')
# Out:
# Total time required: 1.80 s

# %%
# Wake crossing time flags
t1 = 27; t2 = 70

# %% [markdown]
# ## Attitude

# %%
GrAll.plot_vars('phi_deg')
# Out:
# Total time required: 2.59 s

# %%
GrAll.plot_vars('theta_deg')
# Out:
# Total time required: 1.87 s

# %% [markdown]
# ## Flight control system

# %%
GrAll.plot_vars('delta_a', ax_lim=[None, None, -6, 4])
# Out:
# Total time required: 2.60 s

# %%
GrAll.plot_vars('gamma_deg')
# Out:
# Total time required: 2.11 s

# %% [markdown]
# ## Wind speed in body reference frame
#
# For these parameters we are using the <span class="typewr">plot_results</span> function, which plots data from the <span class="typewr">finalresults.csv</span> file, where it was output by JSBSim at a frequency of 120 Hz, a much higher resolution compared to the normal 20 Hz of all the other output files. It is also equal to the interpolation frequency, which means that we are plottig exactly what the pilot felt during the crossing of the wake.

# %%
GrAll.plot_results('Vw_x_kts', ax_lim =[t1, t2, -22, 15])
# Out:
# Total time required: 122.40 s

# %%
GrAll.plot_results('Vw_y_kts', ax_lim =[t1, t2, 6, 26])
# Out:
# Total time required: 114.70 s

# %%
GrAll.plot_results('Vw_z_kts', ax_lim =[t1, t2, -7, 9])
# Out:
# Total time required: 119.76 s

# %% [markdown]
# ## Load factors

# %%
GrAll.plot_results('n_z', ax_lim=[t1, t2, -0.2, 2.6])
# Out:
# Total time required: 125.50 s

# %% [markdown]
# ## Extracting final results

# %%
GrAll.results(XY_turb=[X_t, Y_t], D_turb=D_t, windDir=270, t_lim=[t1, t2], linestyle='-')
# Out:
# Index     Altit.    dist/D    nz_max    nz_min    nz_avg    nz_std    Ww_max    Ww_min    Ww_avg    Ww_std
# ---------------------------------------------------------------------------------------------------------------
# 0001     87.45     12.37      1.69      0.59      0.99      0.07      4.31     -4.90      0.62      0.95
# 0002     74.15     14.47      2.51      0.31      1.00      0.12      9.06     -3.33      2.54      2.11
# 0003     95.16     13.29      1.59      0.55      1.00      0.08      4.65     -4.25      0.64      0.82
# 0004     84.31     14.33      2.13      0.65      1.00      0.08      6.72     -1.89      0.60      0.90
# 0005     91.22     10.66      1.20      0.75      1.00      0.04      5.34     -1.18      0.59      0.92
# 0006     76.78      9.41      1.44      0.69      1.00      0.05      5.19     -1.32      0.65      1.13
# 0007     72.33      9.05      1.46      0.63      1.00      0.04      9.44     -1.04      2.46      2.34
# 0008     82.43      7.19      1.22      0.66      1.00      0.04      9.33     -1.46      2.68      2.30
# 0009     68.83     12.15      1.93      0.40      0.99      0.09      5.25     -1.61      0.80      1.11
# 0010     96.18     15.18      1.67      0.45      1.00      0.07      3.94     -1.90      1.42      0.63
# 0011     82.97      6.92      1.21      0.63      1.00      0.04      9.78     -1.48      2.46      2.46
# 0012     93.15      5.68      1.12      0.51      1.00      0.04      7.70     -1.79      2.51      1.77
# 0013     98.97      9.42      1.64      0.13      1.00      0.07      8.56     -2.05      2.37      2.03
# 0014     92.21      2.27      1.08      0.78      1.00      0.03      4.46     -1.50      0.76      0.92
# 0015     81.63      7.53      1.16      0.75      1.00      0.04      4.35     -1.35      0.55      1.02
# 0016     62.70      7.56      1.15      0.61      1.00      0.04     10.51     -0.59      2.07      2.60
# 0017     72.09      7.74      1.21      0.74      1.00      0.03      5.28     -1.17      1.32      1.41
# 0018     92.04      7.12      1.10      0.61      1.00      0.04      4.29     -1.55      1.15      0.79
# 0019     96.50     10.91      1.75      0.42      1.00      0.07      6.00     -1.37      1.32      0.70
# 0020     94.01      9.09      1.15      0.62      1.00      0.03      3.78     -1.31      1.36      0.68
# 0021     80.96     12.21      2.15     -0.26      1.00      0.10      9.10     -3.68      2.22      2.24
# 0022     93.13     10.24      1.26      0.70      1.00      0.04      3.37     -1.29      0.92      0.67
# 0023     95.97     11.19      1.45      0.76      1.00      0.07      3.53     -2.20      0.12      0.96
# 0024     83.61      7.93      1.14      0.74      1.00      0.04      4.79     -1.69      0.58      0.92
# 0025     68.30     10.50      1.62      0.06      0.99      0.08     10.38     -1.34      1.97      2.57
# 0026     86.23     11.13      1.35      0.68      1.00      0.05      3.67     -1.50      0.80      0.66
# 0027     88.03     14.83      1.49      0.39      1.00      0.08      5.54     -1.49      0.62      0.79
# 0028     87.05     15.86      1.91     -0.21      1.00      0.12      3.41     -3.91      1.48      0.78
# 0029     60.21      9.70      1.39      0.51      1.00      0.05     10.25     -0.37      2.39      2.54
# 0030     68.72      8.65      1.37      0.56      0.99      0.04     10.29     -0.91      1.95      2.56
# 0031     93.42      6.08      1.14      0.69      1.00      0.03      4.26     -1.83      1.08      0.96
# 0032     83.56     12.97      1.39      0.72      1.00      0.06      5.51     -1.95      0.27      0.98
# 0033     88.41     15.55      1.65      0.52      1.00      0.08      2.62     -3.51      0.80      0.72
# 0034    100.20     11.38      1.64      0.27      1.00      0.06      3.64     -1.22      1.11      0.59
# 0035     98.36     10.91      1.69      0.31      1.00      0.05      6.03     -1.51      1.43      0.78
# 0036     83.68     14.89      1.69      0.19      0.99      0.10      4.72     -2.30      0.89      0.57
# 0037     81.66     11.80      1.60      0.45      1.00      0.07      4.50     -2.07      0.27      0.94
# 0038     87.76     12.15      1.40      0.60      1.00      0.06      5.10     -4.11      1.05      0.91
# 0039     83.74     17.48      1.41      0.44      1.00      0.08      3.82     -3.21      0.18      0.69
# 0040     95.85      7.73      1.15      0.66      1.00      0.03      3.83     -1.47      1.52      0.79
# 0041     86.99     12.17      1.55      0.55      1.00      0.07      6.53     -1.56      0.51      1.02
# 0042     89.39      7.79      1.16      0.72      1.00      0.04      4.75     -1.66      0.53      0.98
# 0043     88.15      8.72      1.16      0.77      1.00      0.03      4.12     -1.41      0.84      0.83
# 0044     88.60     16.77      1.91      0.20      1.00      0.09      5.81     -1.21      2.16      1.18
# 0045     86.89     17.12      1.52      0.51      1.00      0.07      5.22     -2.44      0.35      0.93
# 0046     74.41     10.17      1.66      0.60      1.00      0.07      6.15     -0.80      0.49      1.10
# 0047     92.28     16.46      1.54      0.50      1.00      0.08      5.24     -2.90      0.58      0.97
# 0048     93.45      9.09      1.25      0.58      1.00      0.04      7.49     -1.39      2.45      1.67
# 0049     82.35     16.94      1.52      0.39      1.00      0.07      3.74     -0.97      1.41      0.91
# 0050     95.71      4.72      1.10      0.62      1.00      0.04      6.37     -1.48      2.27      1.40
# 0051     95.68     10.60      1.73      0.22      1.00      0.08      8.06     -1.47      1.31      0.74
# 0052     90.41      5.42      1.12      0.65      1.00      0.04      4.25     -1.37      0.70      0.93
# 0053     69.31     11.18      1.40      0.55      1.00      0.07      6.07     -1.26      0.13      1.07
# 0054     94.32     15.68      1.83      0.06      1.00      0.09      3.46     -2.38      1.02      0.59
# 0055     91.58      6.94      1.15      0.78      1.00      0.05      4.53     -1.59      0.30      1.09
# 0056     76.48     10.66      1.78      0.03      0.99      0.08     10.19     -1.26      2.63      2.52
# 0057     85.05     18.38      1.35      0.64      1.00      0.04      7.63      0.29      2.28      1.57
# 0058     89.18     15.71      1.40      0.53      1.00      0.08      4.20     -2.65      0.54      0.75
# 0059     89.34     12.37      1.61      0.28      1.00      0.09      7.30     -4.44      0.80      1.01
# 0060     89.87     14.32      1.68      0.31      1.00      0.08      6.76      1.07      2.53      1.29
# 0061     94.89     11.65      1.72      0.29      1.00      0.07      8.58     -1.49      1.05      0.95
# 0062     84.31     11.64      1.35      0.63      1.00      0.05      6.20     -1.08      0.54      1.06
# 0063     93.96     17.82      1.54      0.36      1.00      0.07      4.91     -2.11      1.99      1.01
# 0064     84.44     15.69      1.69     -0.03      1.00      0.10      8.30     -2.89      2.45      1.85
# 0065     78.23     10.59      1.69      0.49      1.00      0.06      6.09     -0.70      0.65      0.82
# 0066     80.05      7.63      1.14      0.77      1.00      0.03      4.44     -1.10      0.58      0.94
# 0067     92.10      3.03      1.10      0.81      1.00      0.03      4.61     -1.54      0.83      0.90
# 0068     89.96     14.37      1.64      0.29      1.00      0.07      4.79      0.20      1.20      0.64
# 0069     87.84      7.65      1.22      0.71      1.00      0.04      9.03     -1.66      2.18      2.21
# 0070     81.73     12.88      1.44      0.55      1.00      0.07      4.57     -1.34      0.78      0.85
# 0071     82.81     10.90      1.38      0.70      1.00      0.04      5.59     -1.65      0.86      0.91
# 0072     83.96      8.75      1.18      0.69      1.00      0.03      4.23     -1.39      0.87      0.88
# 0073     93.93     13.42      1.66      0.34      1.00      0.09      7.57      0.10      2.52      1.58
# 0074     93.72     15.18      1.60      0.27      1.00      0.08      4.40     -1.69      1.69      0.70
# 0075     84.84      9.40      1.58      0.57      1.00      0.05      4.15     -1.52      0.51      0.88
# 0076     88.76     14.84      1.66      0.38      1.00      0.07      3.78     -0.76      1.28      0.65
# 0077     84.49     13.90      1.76      0.21      1.00      0.09      5.71     -3.61      0.90      1.07
# 0078     81.85     14.03      1.84      0.26      1.00      0.10      5.35     -6.48      0.89      1.31
# 0079     83.32     12.31      1.67      0.33      1.00      0.07      7.94     -2.39      1.09      1.08
# 0080     88.90      9.89      1.72      0.57      1.00      0.05      6.56     -1.62      2.27      1.42
# 0081     84.66     18.31      1.21      0.69      1.00      0.05      2.84     -0.10      0.62      0.34
# 0082     83.56      8.75      1.24      0.75      1.00      0.05      4.78     -1.31      0.40      0.99
# 0083     82.37     16.35      1.45      0.52      0.99      0.08      5.28     -1.18      0.64      1.02
# 0084     98.78     11.06      1.53      0.44      1.00      0.05      5.76     -1.43      1.30      0.74
# 0085     94.08     13.77      1.63      0.28      1.00      0.07      5.59     -2.30      1.73      1.37
# 0086     87.55     13.25      1.67      0.57      1.00      0.06      4.19     -3.59      0.95      0.87
# 0087     86.39      7.80      1.17      0.69      1.00      0.03      4.05     -1.35      1.66      0.79
# 0088     93.16     12.60      1.59      0.06      1.00      0.08      5.23     -0.93      2.08      1.06
# 0089     90.18      8.59      1.12      0.78      1.00      0.04      4.44     -1.36      0.43      1.01
# 0090     92.35     19.67      1.42      0.29      1.00      0.06      4.07     -2.11      1.69      0.92
# 0091     74.42     12.01      1.46      0.29      1.00      0.07      6.37     -3.15      0.21      1.05
# 0092     92.07     12.63      1.64      0.38      1.00      0.07      4.54     -3.12      1.26      0.59
# 0093     86.59      7.63      1.21      0.75      1.00      0.03      4.43     -1.58      1.20      1.00
# 0094     80.21     11.50      1.73      0.49      1.00      0.07      5.60     -1.11      1.05      0.65
# 0095     83.67     15.45      1.70      0.09      1.00      0.11      8.92     -3.44      2.53      2.18
# 0096     88.15      3.98      1.15      0.70      1.00      0.03      5.75     -1.47      2.05      1.31
# 0097     94.02      8.13      1.16      0.70      1.00      0.04      3.94     -1.69      0.94      0.76
# 0098     68.38      9.78      1.75      0.59      0.99      0.06     10.47     -1.14      1.82      2.59
# 0099     83.35      3.53      1.12      0.72      1.00      0.03      8.67     -1.49      2.38      2.15
# 0100     94.96      8.22      1.16      0.68      1.00      0.04      5.01     -1.46      1.98      1.11
