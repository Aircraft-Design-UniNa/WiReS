# %% [markdown]
# <h1 class="heading">Wind Reconstructor</h1>
# <h1>Actuator Line Model - Case (4,1) - Random trajectories</h1>
#
# <h6 class="author"> — <b style="color:rgb(0,51,102);">Carmine Varriale, Agostino De Marco</b>, <i>University of Naples Federico II</i></h6>
#
# ## Introduction
# In this notebook, we are going to simulate the flight of our aircraft through the middle of the wake of a wind turbine.
# The aircraft is a modified version of the Cessna 172 Skyhawk: it has been scaled down from a geometric and inertial point of view, in order to be closer to an Ikarus C42, for which some theoretical results are available from a previous study. The aerodynamic model has not been changed at all, considering that the two aircraft have comparable configurations overall.
# <br><br>
# The turbine is represented by an actuator line model, and the inflow by a uniform velocity field.

# %% [markdown]
# ## Case specific settings
# Wind speed at the actuator disk is $5\ \mathrm{m/s}$. <br>
# Wind direction is $270°$ ccw with respect to local north, but the turbine azimuth angle is $285°$, i.e it is working with $15°$ out-of-axis wind.
# <br>
# <img src="./images/ALM41wakeFromAbove300.png" />
# <img src="./images/ALM41wakeFromAboveUz300.png" />

# %%
% run ./python/nb_init.py
% matplotlib inline

import numpy as np
import utm

import geography as geo
import data_handling as dh
from property_map import pmap
from MCSim import *
# Out:
# <style>
#
# /* Hide top Jupyter bar with logo, filename, last saved, etc. */
# div#header-container {
#     display: none;
# }
#
# #notebook-container {
#     padding: 15px;
#     background-color: #fff;
#     min-height: 0;
#     -webkit-box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.2);
#     box-shadow: 0px 0px 12px 1px rgba(87, 87, 87, 0.2);
#     width: 1050px;
# }
#
#
#
# /* ==================================== */
# /*  Code Cells: selected and unselected */
# /* ==================================== */
#
# /*This prevents scrollable output from having an ugly grey shadow around it*/
#
# div.cell, div.output.output_scroll {
#     box-shadow: none;
# }
#
# /* Interactive figure header */
# .ui-widget-header {
#     border-width: 2px 0px 0px 0px;
#     border-radius: 15px;
#     border-top: solid black;
#     background: white;
#     color: black;
#     font-weight: 800;
# }
#
# /* ============= */
# /* Markdown text */
# /* ============= */
#
# .text_cell_render p,
# .text_cell_render div.main {                     /* Basic Font in Markdown cells */
#     font-family: 'Georgia', serif;
#     font-size: 12pt;
#     line-height: 120%;
#     color: black;
#     font-weight: 100;
#     text-align: justify;
#     display: block;
#     padding: 0px;
#     margin-top: 0pt;
#     margin-bottom: 0pt;
# }
#
# .text_cell_render li {
#     font-family: 'Georgia', serif;
#     font-size: 12pt;
#     line-height: 110%;
#     color: black;
#     font-weight: 100;
#     margin-top: 10pt;
# }
#
# .text_cell_render div.path { /* File and folder paths */
#     font-family: 'Lucida Sans Typewriter', monospace;
#     font-size: 10pt;
#     line-height: 100%;
#     color: black;
#     font-weight: 100;
#     text-align: center;
#     display: block;
#     margin: 8pt 0pt 8pt 0pt;
# }
#
# .text_cell_render div.typewr, .text_cell_render span.typewr { /* Code quotations in markdoown cell */
#     font-family: 'Lucida Sans Typewriter', monospace;
#     font-size: 10pt;
#     line-height: 100%;
#     color: black;
#     font-weight: 100;
#     text-align: center;
#     display: inline;
#     margin: 0pt;
# }
#
# .text_cell_render div.button, .text_cell_render span.button { /* Buttons on keyboard */
#     font-family: 'Calibri', sans;
#     font-size: 10pt;
#     line-height: 100%;
#     color: black;
#     font-weight: 100;
#     text-align: center;
#     display: inline;
#     padding: 0pt 2pt 0pt 2pt;
#     border: solid 1pt black;
#     border-radius: 2px;
# }
#
# .text_cell_render span.varstr {  /* Variable of type string */
#     color: #CC0000;
# }
#
# .text_cell_render span.varnum {  /* Variable of type number */
#     color: #00994C;
# }
#
# .text_cell_render span.varbool {  /* Variable of type bool */
#     color: #3333FF;
# }
#
#
# .text_cell_render h1.heading { /* Heading */
#     font-family: 'Times', serif;
#     font-style: regular;
#     font-weight: 600;
#     font-size: 24pt;
#     line-height: 100%;
#     text-align: center;
#     background-color: rgb(0,51,102);
#     color: white;
#     margin: 0.0em 0.0em 0.0em 0.0em;
#     padding: 0.3em 0.0em 0.3em 0.0em;
#     display: block;
# }
#
# .text_cell_render h1 { /* Title */
#     font-family: 'Times', serif;
#     font-style: regular;
#     font-weight: 600;
#     font-size: 24pt;
#     line-height: 100%;
#     text-align: center;
#     color: rgb(0,51,102);
#     background-color: #fff;
#     border-style: solid;
#     border-width: 1.5pt;
#     border-color: rgb(0,51,102);
#     margin: auto;
#     margin-bottom: 0.8em;
#     padding: 0.5em;
#     display: block;
# }
#
# .text_cell_render h2 { /* Section */
#     font-family: 'Times', serif;
#     font-weight: 600;
#     font-size: 20pt;
#     line-height: 100%;
#     color: rgb(0,51,102);
#     padding-top: 0.9em;
#     padding-bottom: 0.3em;
#     margin-bottom: 0.0em;
#     margin-top: 0.0em;
#     display: block;
# }
#
# .text_cell_render h3 { /* Subsection */
#     font-family: 'Times', serif;
#     font-size: 16pt;
#     font-weight: 600;
#     margin-top:0.0em;
#     margin-bottom: 0.0em;
#     padding-top: 0.7em;
#     padding-bottom: 0.3em;
#     font-style: regular;
#     color: rgb(0,51,102);
# }
#
# .text_cell_render h4 {    /* Caption */
#     font-family: 'Times', serif;
#     font-size: 14pt;
#     text-align: center;
#     margin-top: 0em;
#     margin-bottom: 2em;
#     font-style: regular;
# }
#
# .text_cell_render h5 {  /* Small titles */
#     font-family: 'Times', sans-serif;
#     font-weight: 400;
#     font-size: 16pt;
#     color: rgb(163,0,0);
#     font-style: italic;
#     margin-bottom: .1em;
#     margin-top: 0.8em;
#     display: block;
# }
#
# .text_cell_render h6.author { /* Author heading */
#     font-family: 'PT Mono', sans-serif;
#     font-style: normal;
#     font-weight: 500;
#     font-size: 10pt;
#     line-height: 100%;
#     color: black;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
#
# .text_cell_render h6.copyright { /* Copyright note */
#     font-family: 'PT Mono', sans-serif;
#     font-weight: 300;
#     font-size: 9pt;
#     line-height: 100%;
#     color: grey;
#     margin-bottom: 1px;
#     margin-top: 1px;
# }
#
# </style>
#
# <script>
#     MathJax.Hub.Config({
#                         TeX: {
#                            extensions: ["AMSmath.js"],
#                            equationNumbers: { autoNumber: "AMS", useLabelIds: true}
#                            },
#                 tex2jax: {
#                     inlineMath: [ ['$','$'], ["\\(","\\)"] ],
#                     displayMath: [ ['$$','$$'], ["\\[","\\]"] ]
#                 },
#                 displayAlign: 'center', // Change this to 'center' to center equations.
#                 "HTML-CSS": {
#                     styles: {'.MathJax_Display': {"margin": 4}}
#                 }
#         });
# </script>

# %%
# Turbine diameter
D_t = 126 #m

# Min and Max distance from the disk, in terms of turbine diameters
minD_t = -0.8 ; maxD_t = 18

# Assign turbine Lat-Lon coordinates and height
Lat_t = 53.153588 #deg
Lon_t = 8.162655  #deg
H_t   = 90      #m

# Calculate turbine UTM coordinates
X_t, Y_t, zone_num, zone_lett = utm.from_latlon(Lat_t, Lon_t)
print("X_t =  {0:.14f} m (Easting coord.)".format(X_t), sep="")
print("Y_t =  {0:.14f} m (Northing coord.)".format(Y_t), sep="")
# Out:
# X_t =  444005.64156725001521 m (Easting coord.)
# Y_t =  5889683.58956928178668 m (Northing coord.)

# %% [markdown]
# <div class="main">
# At this point, we can <b>manually</b> translate the whole mesh in order to give the turbine the above coordinates in UTM reference frame. By default, the simulation has been run with turbine base position being $(0.0 , 0.0, -90.0)\ \mathrm{m}$ and tower height being $90.0\ \mathrm{m}$, so the center of the disk is supposed to be at $z_t =0.0\ \mathrm{m}$.
# <br><br>
# The command to run in the OpenFoam case directory in order to translate the mesh is derived as follows

# %%
x_t = 0.0; y_t = 0.0; z_t = 0.0;

delta_X = X_t - x_t
delta_Y = Y_t - y_t
delta_Z = H_t - z_t

print('transformPoints -translate "(',delta_X,' ',delta_Y,' ',delta_Z,')"', ' >& log.transformPoints &', sep='')
# Out:
# transformPoints -translate "(444005.64156725 5889683.589569282 90.0)" >& log.transformPoints &

# %% [markdown]
# For a quick check on mesh quality, it might be worth to also execute
# <div class="path">checkMesh >& log.checkMesh &</div>
# </div>
#
# At this point, we have the full set of initial and corresponding final positions of the aircraft. Our goal is to create a simulation family for each of this couples: within the family, initial speed will be fixed while initial position with respect to the turbine will vary, thanks to the already well known <span class="typewr">generate_series</span> function. Finally, the aircraft initial speed and altitude will also be iterated in the set, through a simple external <span class="typewr">for</span> loop.
#
# ## Simulation control panel

# %%
for i in range(0,10):  #100 simulations in total, 10 at a time for memory reasons
    
    N = 10
    script     = 'c172mod_OF_ALM_random'
    autopilot  = 'c172ap_unina_mod'
    output_fol = 'c172mod_OF_ALM41_random-' + str(i) 

    # Creating instance of the class
    ALM41r = WRSimFamily(N, 
                        seed_name      = script,
                        autopilot_name = autopilot,
                        out_foldername = output_fol,
                        port_num=1025)

    # Initial position
    X0 = ALM41r.generate_series('', 'uniform', [X_t + minD_t*D_t, X_t + maxD_t*D_t])
    Y0 = Y_t - 1500

    # Calculate waypoints positions in UTM
    X1 = ALM41r.generate_series('', 'uniform', [X_t + minD_t*D_t, X_t + maxD_t*D_t])
    Y1 = Y_t + 1500

    # Convert such positions to Lat-Lon coordinates
    def LatLon_from_utm(X, Y, zone_num, zone_lett):
        LatLon = [utm.to_latlon(X[i], Y, zone_num, zone_lett) for i in range(N)]
        Lat = [LatLon[i][0] for i in range(len(X))] #deg
        Lon = [LatLon[i][1] for i in range(len(X))] #deg
        return Lat, Lon

    Lat0, Lon0 = LatLon_from_utm(X0, Y0, zone_num, zone_lett)
    Lat1, Lon1 = LatLon_from_utm(X1, Y1, zone_num, zone_lett)

    # Initial positions
    ALM41r.generate_series('latitude', 'from_list', Lat0)
    ALM41r.generate_series('longitude', 'from_list', Lon0)

    # Waypoint positions
    ALM41r.generate_series('guidance/target-wp-latitude-rad-final',  'from_list', np.radians(Lat1))
    ALM41r.generate_series('guidance/target-wp-longitude-rad-final', 'from_list', np.radians(Lon1))

    # Flight parameters
    h_m       = ALM41r.generate_series('altitude', 'gaussian', [H_t+25, 5])
    psi_deg   = ALM41r.set_value('psi', 0)
    gamma_deg = ALM41r.set_value('gamma', -1)
    V_kts     = ALM41r.generate_series('vt', 'uniform', [50, 100])

    # Launch family of simulations
    #ALM41r.launch_mc_sim(log='off', system='linux')

# %% [markdown]
# Now we will have to merge files ad folders accordingly. This can be done manually or via a bash script, for example

# %%
GrAll = PostGroup('c172mod_OF_ALM41_random', 'c172x_unina_mod', list(range(1,100+1)),'All')
#GrAll.get_traj_in_UTM()
GrAll.load_traj_in_UTM()
# Out:
# Total time required: 195.71 s

# %% [markdown]
# ## Trajectory

# %%
GrAll.plot_ground_track_UTM(origin=[X_t, Y_t], ax_lim=[None, None, -1510, +1510])
# Out:
# Total time required: 4.87 s

# %%
GrAll.plot_vars('h_agl_m')
# Out:
# Total time required: 2.62 s

# %%
GrAll.plot_traj3D_UTM(origin=[X_t, Y_t], Hdisk=H_t, to_scale='XY', ax_lim=[0,2300,-1600,1600,50,130], \
                    nticks=[11,11,9], view=(40,160), legend='off')
# Out:
# Total time required: 4.00 s

# %% [markdown]
# ## Wind speed in UTM reference frame
# We look at the Eastern component to understand when the aircraft actually enters the wake for the wind deficit makes it as clear as possible. We therefore use this time history as a visual reference for our further observations.

# %%
GrAll.plot_vars('Vw_E_kts')
# Out:
# Total time required: 1.74 s

# %%
# Wake crossing time flags
t1 = 25; t2 = 81

# %% [markdown]
# ## Attitude

# %%
GrAll.plot_vars('phi_deg')
# Out:
# Total time required: 1.74 s

# %%
GrAll.plot_vars('theta_deg')
# Out:
# Total time required: 3.01 s

# %% [markdown]
# ## Flight control system

# %%
GrAll.plot_vars('delta_a', ax_lim=[None, None, -4, 4])
# Out:
# Total time required: 1.87 s

# %%
GrAll.plot_vars('gamma_deg')
# Out:
# Total time required: 1.60 s

# %% [markdown]
# ## Wind speed in body reference frame
#
# For these parameters we are using the <span class="typewr">plot_results</span> function, which plots data from the <span class="typewr">finalresults.csv</span> file, where it was output by JSBSim at a frequency of 120 Hz, a much higher resolution compared to the normal 20 Hz of all the other output files. It is also equal to the interpolation frequency, which means that we are plottig exactly what the pilot felt during the crossing of the wake.

# %%
GrAll.plot_results('Vw_x_kts', ax_lim =[t1, t2, -9, 9])
# Out:
# Total time required: 85.97 s

# %%
GrAll.plot_results('Vw_y_kts', ax_lim =[t1, t2, 0, 12])
# Out:
# Total time required: 90.72 s

# %%
GrAll.plot_results('Vw_z_kts', ax_lim =[t1, t2, -3, 4])
# Out:
# Total time required: 98.11 s

# %% [markdown]
# ## Load factors

# %%
GrAll.plot_vars('n_z', ax_lim=[t1, t2, 0.2, 1.8])
# Out:
# Total time required: 1.73 s

# %% [markdown]
# ## Extracting final results

# %%
GrAll.results(XY_turb=[X_t, Y_t], D_turb=D_t, windDir=270, t_lim=[t1, t2], linestyle='-')
# Out:
# Index     Altit.    dist/D    nz_max    nz_min    nz_avg    nz_std    Ww_max    Ww_min    Ww_avg    Ww_std
# ---------------------------------------------------------------------------------------------------------------
# 0001     80.26      8.04      1.27      0.67      0.99      0.03      3.34     -1.23      0.29      0.57
# 0002     84.27      9.19      1.35      0.46      1.00      0.04      2.50     -0.74      0.47      0.36
# 0003     85.39     15.03      1.00      0.99      1.00      0.00      0.49      0.12      0.23      0.09
# 0004     68.56     10.76      1.09      0.91      1.00      0.01      0.58     -0.35      0.31      0.08
# 0005     85.09      5.68      1.52      0.55      0.99      0.04      3.39     -2.01      0.34      0.62
# 0006     83.00      0.70      1.02      0.95      1.00      0.01      1.16     -0.47      0.12      0.24
# 0007     88.80     12.10      1.02      0.98      1.00      0.01      0.17      0.05      0.10      0.03
# 0008     87.84     10.88      1.02      0.98      1.00      0.00      3.33      0.06      0.53      0.59
# 0009     85.87     16.80      1.00      0.99      1.00      0.00      0.54      0.10      0.22      0.10
# 0010     87.09      9.22      1.24      0.74      1.00      0.03      1.46     -0.42      0.35      0.19
# 0011     87.58     12.31      1.00      0.99      1.00      0.00     -0.06     -0.09     -0.08      0.01
# 0012     90.17      8.75      1.16      0.81      1.00      0.03      2.33     -1.02      0.18      0.34
# 0013     81.37      9.62      1.06      0.94      1.00      0.02      0.44     -0.44      0.10      0.10
# 0014     84.69     12.65      1.00      0.99      1.00      0.00      3.24      0.10      0.43      0.54
# 0015     81.94     12.33      1.01      0.97      1.00      0.01      3.23     -0.08      0.29      0.52
# 0016     87.32      7.75      1.18      0.77      1.00      0.03      1.46     -0.95      0.09      0.16
# 0017     76.63     13.12      1.00      1.00      1.00      0.00      1.14      0.22      0.38      0.17
# 0018     88.76     15.04      1.00      0.99      1.00      0.00      2.43      0.26      0.53      0.36
# 0019     57.51      8.08      1.52      0.63      0.99      0.05      3.09     -1.00      0.09      0.39
# 0020     88.12      8.62      1.16      0.83      1.00      0.03      1.34     -0.30      0.24      0.20
# 0021     79.54      5.00      1.45      0.74      1.00      0.04      2.99     -1.54      0.42      0.57
# 0022     88.69      2.49      1.07      0.95      1.00      0.01      3.17     -0.83      0.48      0.57
# 0023     92.28      3.87      1.19      0.77      1.00      0.02      3.42     -0.58      0.46      0.63
# 0024     88.75     12.35      1.01      0.98      0.99      0.01      3.26     -0.01      0.34      0.54
# 0025     83.82      7.42      1.16      0.76      1.00      0.03      1.31     -1.04      0.20      0.28
# 0026     84.18     12.43      1.00      0.98      0.99      0.01      3.27      0.05      0.39      0.55
# 0027     87.28      7.04      1.76      0.55      0.99      0.06      3.44     -2.45      0.42      0.71
# 0028     77.29      4.33      1.32      0.83      1.00      0.03      1.31     -0.66      0.10      0.20
# 0029     93.57     13.23      1.00      0.99      1.00      0.00      2.67      0.17      0.45      0.40
# 0030     91.17     16.32      1.00      0.99      1.00      0.00      2.84      0.11      0.40      0.44
# 0031     85.24      4.74      1.16      0.81      1.00      0.02      2.16     -1.41      0.21      0.36
# 0032     90.69     15.55      1.02      0.98      1.00      0.01      0.65     -0.02      0.17      0.14
# 0033     86.94      9.44      1.39      0.39      1.00      0.04      3.08     -1.90      0.52      0.56
# 0034     86.06      8.02      1.18      0.75      1.00      0.02      3.04     -0.68      0.45      0.49
# 0035     69.62      8.64      1.34      0.74      0.99      0.04      1.80     -1.08      0.02      0.31
# 0036     89.51     12.87      1.00      0.99      1.00      0.00      1.90      0.23      0.45      0.25
# 0037     85.84     12.02      1.03      0.97      1.00      0.01      0.14      0.06      0.10      0.02
# 0038     89.54      9.67      1.29      0.75      1.00      0.03      1.86     -0.83      0.08      0.15
# 0039     98.06     17.66      1.00      0.99      1.00      0.00      3.11      0.14      0.48      0.52
# 0040     89.96     13.11      1.00      0.99      1.00      0.00      3.18      0.18      0.54      0.54
# 0041     99.78     10.17      1.21      0.89      1.00      0.02      2.89     -0.56      0.55      0.46
# 0042     87.88      6.80      1.27      0.69      1.00      0.03      2.65     -1.51      0.43      0.44
# 0043     84.68     13.49      1.01      0.98      0.99      0.01      3.25      0.01      0.35      0.54
# 0044     79.01      1.96      1.05      0.96      1.00      0.01      3.12     -0.57      0.38      0.54
# 0045     88.81     12.24      1.01      0.97      0.99      0.01      3.24     -0.10      0.27      0.53
# 0046     88.18     17.00      1.00      0.99      1.00      0.00      0.50      0.12      0.24      0.09
# 0047     82.17     12.50      1.00      0.99      1.00      0.00      1.95      0.22      0.47      0.26
# 0048     86.98      5.04      1.33      0.74      1.00      0.03      3.28     -0.96      0.13      0.35
# 0049     89.01     10.05      1.19      0.87      1.00      0.02      1.45     -0.89      0.18      0.13
# 0050     83.44     11.14      1.00      0.98      1.00      0.00      2.39      0.18      0.44      0.34
# 0051     80.39     16.07      1.00      0.99      1.00      0.00      1.04      0.14      0.31      0.18
# 0052     92.75     10.06      1.14      0.89      1.00      0.02      1.16     -0.98      0.08      0.13
# 0053     84.10      6.28      1.35      0.39      1.00      0.04      3.17     -1.98      0.34      0.57
# 0054     85.14      8.81      1.30      0.65      1.00      0.03      2.70     -0.53      0.55      0.43
# 0055     85.27     10.23      1.11      0.88      1.00      0.01      0.87     -0.66      0.11      0.09
# 0056     80.57      4.06      1.28      0.59      1.00      0.03      3.51     -0.62      0.49      0.68
# 0057     98.92      8.54      1.17      0.79      1.00      0.02      2.90     -0.11      0.54      0.46
# 0058     73.42      9.42      1.07      0.92      0.99      0.02      0.98     -0.43      0.04      0.25
# 0059     83.52     10.53      1.01      0.95      1.00      0.01      3.35     -0.10      0.43      0.58
# 0060     86.76     12.73      1.01      0.99      1.00      0.01      0.27      0.05      0.14      0.05
# 0061     92.01      6.96      1.27      0.85      1.00      0.02      0.93     -1.23      0.13      0.16
# 0062     91.44     16.17      1.00      0.99      1.00      0.00      1.00      0.09      0.27      0.19
# 0063     80.50      3.33      1.05      0.94      1.00      0.02      0.80     -0.57      0.07      0.23
# 0064     90.17      8.95      1.23      0.78      1.00      0.03      2.70     -0.48      0.56      0.47
# 0065     80.65     11.31      1.03      0.98      1.00      0.01      0.34     -0.11      0.11      0.10
# 0066     87.43     12.05      1.00      0.99      1.00      0.00      3.27      0.17      0.54      0.57
# 0067     91.87      5.98      1.37      0.56      1.00      0.04      3.24     -1.78      0.51      0.59
# 0068     92.72     16.54      1.01      0.99      1.00      0.00      0.19      0.07      0.12      0.03
# 0069     87.67     11.83      1.01      0.98      1.00      0.00      0.27      0.08      0.14      0.05
# 0070     83.71      9.49      1.08      0.88      1.00      0.02      0.91     -0.93      0.17      0.21
# 0071     82.60     11.08      1.01      0.98      1.00      0.00      0.96      0.20      0.40      0.13
# 0072     78.83      9.56      1.16      0.80      1.00      0.02      1.11     -0.92     -0.07      0.18
# 0073     90.16     15.88      1.00      0.99      0.99      0.00      3.26      0.12      0.46      0.57
# 0074     87.06      8.84      1.31      0.76      1.00      0.02      1.47     -0.61      0.20      0.11
# 0075     86.37      7.06      1.30      0.69      1.00      0.03      3.28     -1.94      0.31      0.59
# 0076     89.53      7.57      1.34      0.74      1.00      0.04      3.16     -0.17      0.59      0.55
# 0077     92.74      4.95      1.36      0.79      1.00      0.03      1.93     -1.01      0.14      0.24
# 0078     83.35     11.62      1.07      0.95      1.00      0.03      0.32     -0.17      0.11      0.10
# 0079     81.07     12.75      1.00      0.99      1.00      0.00      2.12      0.25      0.49      0.29
# 0080     90.66     13.02      1.01      0.99      1.00      0.01      0.12      0.04      0.08      0.02
# 0081     89.38      7.19      1.71      0.71      1.00      0.04      3.35     -2.33      0.47      0.61
# 0082     88.62     10.56      1.02      0.97      0.99      0.01      3.30     -0.16      0.30      0.55
# 0083     81.16      9.28      1.23      0.53      1.00      0.03      2.10     -1.26      0.09      0.17
# 0084     80.88      5.55      1.34      0.81      1.00      0.03      2.30     -1.20      0.15      0.25
# 0085     88.64     17.64      1.01      0.98      1.00      0.00      0.44      0.08      0.19      0.09
# 0086     84.70      9.57      1.23      0.80      0.99      0.02      3.32     -0.68      0.31      0.56
# 0087     86.19      4.82      1.33      0.77      1.00      0.03      2.10     -1.52      0.36      0.40
# 0088     86.72      9.16      1.35      0.78      1.00      0.03      1.89     -0.55      0.39      0.17
# 0089     89.88     10.80      1.02      0.97      1.00      0.01      0.25      0.03      0.12      0.04
# 0090     86.81     11.02      1.01      0.99      1.00      0.00      0.47      0.17      0.32      0.05
# 0091     87.10     13.68      1.02      0.98      1.00      0.01      0.12      0.06      0.09      0.01
# 0092     75.79      9.80      1.03      0.93      1.00      0.02      0.74     -0.32      0.06      0.21
# 0093     92.54      9.22      1.51      0.70      1.00      0.04      3.02     -1.75      0.55      0.56
# 0094     95.23     12.75      1.00      0.99      1.00      0.00      2.87      0.19      0.50      0.45
# 0095     82.93     10.45      1.02      0.94      0.99      0.01      3.33     -0.23      0.38      0.56
# 0096     89.06      2.41      1.07      0.95      1.00      0.01      0.80     -0.77      0.15      0.24
# 0097     76.94      5.17      1.58      0.25      0.99      0.06      3.42     -2.10      0.33      0.73
# 0098     89.81     11.43      1.00      0.98      1.00      0.00      0.34      0.23      0.28      0.03
# 0099     87.13     12.91      1.00      0.99      1.00      0.00      3.24      0.15      0.51      0.56
# 0100     82.92      3.29      1.06      0.94      1.00      0.01      3.41     -0.63      0.44      0.63
